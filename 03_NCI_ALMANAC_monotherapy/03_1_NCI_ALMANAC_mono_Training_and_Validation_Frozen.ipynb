# %%
# import numpy and pandas
import numpy as np
import pandas as pd
import csv
import matplotlib.pyplot as plt
# %matplotlib inline
import seaborn as sns

# %config Completer.use_jedi=False
import os

#import sklearn for cross validation|
from sklearn.model_selection import StratifiedKFold, GridSearchCV
from sklearn.model_selection import KFold,cross_val_predict,cross_val_score,cross_validate

#import keras modules
import tensorflow as tf
from tensorflow import keras
import keras.backend as K
import keras.backend.tensorflow_backend as KTF
import keras
import keras.layers
from keras.layers import Layer 
import keras.initializers
from keras.models import Model, Sequential,load_model
from keras.layers import Input, Dense, Dropout, BatchNormalization, Activation, Embedding, Lambda, Flatten, Multiply, multiply,dot, add,subtract
from keras.layers import Concatenate,concatenate,LeakyReLU,maximum,minimum
from keras.optimizers import Adam
from keras.regularizers import l2,l1
from keras.preprocessing import sequence
from keras.engine.topology import Layer, InputSpec

from keras.utils import plot_model
from IPython.display import SVG


from sklearn.metrics import precision_recall_curve, auc, roc_curve

#import rdkit
import rdkit
import rdkit.Chem as Chem
from rdkit.Chem import AllChem
from rdkit.Chem.Fingerprints import FingerprintMols

#fix the random seed
np.random.seed(5)

import pickle
import random
# Out:
# Using TensorFlow backend.

# %%
GeneExpression_with_Symbol=pd.read_csv('/DAS_Storage4/ijjin/Study_2/CellLine/CCLE_expression_zscore.csv',index_col=0)
valid_gene_list=GeneExpression_with_Symbol.columns

# %%
GeneSet_List=[]
GeneSetFile='/DAS_Storage1/ijjin/Personal_studies/Drug-Cancer_reponse/geneset/c2.cp.kegg.v7.5.1.symbols.gmt'
with open(GeneSetFile) as f:
    reader = csv.reader(f)
    data = list(list(rec) for rec in csv.reader(f, delimiter='\t')) #reads csv into a list of lists
    for row in data:
        GeneSet_List.append(row)

GeneSet_Dic={}
for GeneSet in GeneSet_List:
    GeneSet_Dic[GeneSet[0]]=GeneSet[2:]
GeneSet_Dic_withoutNA={}
for GeneSet in GeneSet_Dic:
    GeneSet_tmp=pd.Series(GeneSet_Dic[GeneSet])
    GeneSet_tmp=GeneSet_tmp[GeneSet_tmp.isin(valid_gene_list)]
    GeneSet_Dic_withoutNA[GeneSet]=GeneSet_tmp

# %%
def plcc_loss(y_true, y_pred):  
    x = y_true
    y = y_pred
    mx = K.mean(x)
    my = K.mean(y)
    xm, ym = x-mx, y-my
    r_num = K.sum(tf.multiply(xm,ym))
    r_den = K.sqrt(tf.multiply(K.sum(K.square(xm)), K.sum(K.square(ym)))) + 1e-12
    r = r_num / r_den
    r = K.maximum(K.minimum(r, 1.0), -1.0)
    return 1 - r 

def aggregated_loss(y_true,y_pred):
    mse_value=tf.keras.metrics.mse(y_true,y_pred)
    pearson_loss=plcc_loss(y_true,y_pred)
    return mse_value+pearson_loss
    
    
def plcc_metric(y_true, y_pred):  
    x = y_true
    y = y_pred
    mx = K.mean(x)
    my = K.mean(y)
    xm, ym = x-mx, y-my
    r_num = K.sum(tf.multiply(xm,ym))
    r_den = K.sqrt(tf.multiply(K.sum(K.square(xm)), K.sum(K.square(ym)))) + 1e-12
    return r_num / r_den

# %%
K.clear_session()
def get_session(gpu_fraction=0.1):

    gpu_options = tf.GPUOptions(visible_device_list="0",per_process_gpu_memory_fraction=gpu_fraction)
    return tf.Session(config=tf.ConfigProto(allow_soft_placement=True,gpu_options=gpu_options))

KTF.set_session(get_session())
# Out:
# WARNING:tensorflow:From /usr/local/lib/python3.7/site-packages/keras/backend/tensorflow_backend.py:95: The name tf.reset_default_graph is deprecated. Please use tf.compat.v1.reset_default_graph instead.
#
# WARNING:tensorflow:From /usr/local/lib/python3.7/site-packages/keras/backend/tensorflow_backend.py:98: The name tf.placeholder_with_default is deprecated. Please use tf.compat.v1.placeholder_with_default instead.
#
# WARNING:tensorflow:From /usr/local/lib/python3.7/site-packages/keras/backend/tensorflow_backend.py:102: The name tf.get_default_graph is deprecated. Please use tf.compat.v1.get_default_graph instead.
#
# WARNING:tensorflow:From /tmp/ipykernel_47742/554128727.py:4: The name tf.GPUOptions is deprecated. Please use tf.compat.v1.GPUOptions instead.
#
# WARNING:tensorflow:From /tmp/ipykernel_47742/554128727.py:5: The name tf.Session is deprecated. Please use tf.compat.v1.Session instead.
#
# WARNING:tensorflow:From /tmp/ipykernel_47742/554128727.py:5: The name tf.ConfigProto is deprecated. Please use tf.compat.v1.ConfigProto instead.
# 2022-11-25 16:10:15.398781: I tensorflow/core/platform/cpu_feature_guard.cc:142] Your CPU supports instructions that this TensorFlow binary was not compiled to use: AVX2 AVX512F FMA
# 2022-11-25 16:10:15.439143: I tensorflow/core/platform/profile_utils/cpu_utils.cc:94] CPU Frequency: 2300000000 Hz
# 2022-11-25 16:10:15.446279: I tensorflow/compiler/xla/service/service.cc:168] XLA service 0x26131450 initialized for platform Host (this does not guarantee that XLA will be used). Devices:
# 2022-11-25 16:10:15.446338: I tensorflow/compiler/xla/service/service.cc:176]   StreamExecutor device (0): Host, Default Version
# 2022-11-25 16:10:15.452562: I tensorflow/stream_executor/platform/default/dso_loader.cc:44] Successfully opened dynamic library libcuda.so.1
# 2022-11-25 16:10:15.576086: I tensorflow/compiler/xla/service/service.cc:168] XLA service 0x1d8f18c0 initialized for platform CUDA (this does not guarantee that XLA will be used). Devices:
# 2022-11-25 16:10:15.576166: I tensorflow/compiler/xla/service/service.cc:176]   StreamExecutor device (0): NVIDIA TITAN V, Compute Capability 7.0
# 2022-11-25 16:10:15.577512: I tensorflow/core/common_runtime/gpu/gpu_device.cc:1618] Found device 0 with properties:
# name: NVIDIA TITAN V major: 7 minor: 0 memoryClockRate(GHz): 1.455
# pciBusID: 0000:3b:00.0
# 2022-11-25 16:10:15.578132: I tensorflow/stream_executor/platform/default/dso_loader.cc:44] Successfully opened dynamic library libcudart.so.10.0
# 2022-11-25 16:10:15.580623: I tensorflow/stream_executor/platform/default/dso_loader.cc:44] Successfully opened dynamic library libcublas.so.10.0
# 2022-11-25 16:10:15.582970: I tensorflow/stream_executor/platform/default/dso_loader.cc:44] Successfully opened dynamic library libcufft.so.10.0
# 2022-11-25 16:10:15.583646: I tensorflow/stream_executor/platform/default/dso_loader.cc:44] Successfully opened dynamic library libcurand.so.10.0
# 2022-11-25 16:10:15.586328: I tensorflow/stream_executor/platform/default/dso_loader.cc:44] Successfully opened dynamic library libcusolver.so.10.0
# 2022-11-25 16:10:15.587781: I tensorflow/stream_executor/platform/default/dso_loader.cc:44] Successfully opened dynamic library libcusparse.so.10.0
# 2022-11-25 16:10:15.591235: I tensorflow/stream_executor/platform/default/dso_loader.cc:44] Successfully opened dynamic library libcudnn.so.7
# 2022-11-25 16:10:15.592013: I tensorflow/core/common_runtime/gpu/gpu_device.cc:1746] Adding visible gpu devices: 0
# 2022-11-25 16:10:15.592077: I tensorflow/stream_executor/platform/default/dso_loader.cc:44] Successfully opened dynamic library libcudart.so.10.0
# 2022-11-25 16:10:15.593761: I tensorflow/core/common_runtime/gpu/gpu_device.cc:1159] Device interconnect StreamExecutor with strength 1 edge matrix:
# 2022-11-25 16:10:15.593778: I tensorflow/core/common_runtime/gpu/gpu_device.cc:1165]      0
# 2022-11-25 16:10:15.593784: I tensorflow/core/common_runtime/gpu/gpu_device.cc:1178] 0:   N
# 2022-11-25 16:10:15.594575: I tensorflow/core/common_runtime/gpu/gpu_device.cc:1304] Created TensorFlow device (/job:localhost/replica:0/task:0/device:GPU:0 with 1206 MB memory) -> physical GPU (device: 0, name: NVIDIA TITAN V, pci bus id: 0000:3b:00.0, compute capability: 7.0)

# %%
NCI_ALMANAC_mono=pd.read_csv('/DAS_Storage4/ijjin/Study_2/220921_Final/Single/NCI_ALMANAC_mono/221114_NCI_ALMANAC_mono_valid.csv',index_col=0)
NCI_ALMANAC_randomized=NCI_ALMANAC_mono.sample(frac=1)
NCI_ALMANAC_randomized=NCI_ALMANAC_randomized.reset_index(drop=True)
NCI_ALMANAC_randomized=NCI_ALMANAC_randomized[['NSC','CONC','CellName','PERCENTGROWTH']]

# %%
#Cell line feature
X_origin=[pd.read_csv('/DAS_Storage4/ijjin/Study_2/220921_Final/CellLine/Input/'+str(x)+'.csv',index_col=0) for x in range(len(GeneSet_Dic_withoutNA))]
X_origin=[df.loc[NCI_ALMANAC_randomized.CellName] for df in X_origin]
#Drug feature
Drug=pd.read_csv('/DAS_Storage4/ijjin/Study_2/220921_Final/Drug/NCI60_compound_Morgan512.csv',index_col=0)
X_origin.append(Drug.loc[NCI_ALMANAC_randomized.NSC])
#Dose feature
X_origin.append(NCI_ALMANAC_randomized[['CONC']])

# %%
test_Response_list=range(0,int(len(NCI_ALMANAC_randomized)*1/10))
training_Response_list=range(int(len(NCI_ALMANAC_randomized)*1/10),int(len(NCI_ALMANAC_randomized)*9/10))
validation_Response_list=range(int(len(NCI_ALMANAC_randomized)*9/10),(len(NCI_ALMANAC_randomized)))

# %%
#relu
def Making_Model():
    #model_parameter=load_model('/DAS_Storage4/ijjin/Study_2/Single/NCI60_March22/Parameter/Model/220507_training_validation.hdf5',compile=False)

    #Make Model for each gene set, that consists of multiple genes_attention by built-in(2019/05/08)
    initializer = tf.keras.initializers.he_uniform()

    #Drug level
    Drug_feature_length=512
    Drug_Input=Input((Drug_feature_length,), dtype='float32', name='Drug_Input')
    Drug_Input=Input((Drug_feature_length,), dtype='float32')

    Drug_Dense1=Dense(256, name='Drug_Dense_1',kernel_initializer=initializer)(Drug_Input)
    Drug_Dense1=BatchNormalization()(Drug_Dense1)
    Drug_Dense1=Activation('relu', name='Drug_RELU_1')(Drug_Dense1)

    Drug_Dense2=Dense(128, name='Drug_Dense_2',kernel_initializer=initializer)(Drug_Dense1)
    Drug_Dense2=BatchNormalization()(Drug_Dense2)
    Drug_Dense2=Activation('relu', name='Drug_RELU_2')(Drug_Dense2)

    Drug_Dense_New1=Dense(128, name='Drug_Dense_New1',kernel_initializer=initializer)(Drug_Input)
    Drug_Dense_New1=BatchNormalization()(Drug_Dense_New1)
    Drug_Dense_New1=Activation('relu', name='Drug_RELU_New1')(Drug_Dense_New1)

    Drug_Dense_New2=Dense(32, name='Drug_Dense_New2',kernel_initializer=initializer)(Drug_Dense_New1)
    Drug_Dense_New2=BatchNormalization()(Drug_Dense_New2)
    Drug_Dense_New2=Activation('relu', name='Drug_RELU_New2')(Drug_Dense_New2)
    
    #Gene level
    GeneSet_Model=[]
    GeneSet_Input=[]
    for GeneSet in GeneSet_Dic_withoutNA.keys():
        Gene_Input=Input(shape=(len(GeneSet_Dic_withoutNA[GeneSet]),),dtype='float32', name=GeneSet+'_Input')
        
        Drug_effected_Model_for_Attention=[Gene_Input]
        Drug_Dense_Geneset=Dense(int(len(GeneSet_Dic_withoutNA[GeneSet])/4)+1,dtype='float32',name=GeneSet+'_Drug',kernel_initializer=initializer)(Drug_Dense_New2)
        Drug_Dense_Geneset=BatchNormalization(name=GeneSet+'_Drug_Batch')(Drug_Dense_Geneset)
        Drug_Dense_Geneset=Activation('relu', name=GeneSet+'Drug_RELU')(Drug_Dense_Geneset)
        Drug_effected_Model_for_Attention.append(Drug_Dense_Geneset) #Drug feature to attention layer
        Gene_Concat=concatenate(Drug_effected_Model_for_Attention,axis=1,name=GeneSet+'_Concat')
        Gene_Attention = Dense(len(GeneSet_Dic_withoutNA[GeneSet]), activation='tanh', name=GeneSet+'_Attention_Dense',kernel_initializer=initializer)(Gene_Concat)
        Gene_Attention=Activation(activation='softmax', name=GeneSet+'_Attention_Softmax')(Gene_Attention)
        Attention_Dot=dot([Gene_Input,Gene_Attention],axes=1,name=GeneSet+'_Dot')
        Attention_Dot=BatchNormalization(name=GeneSet+'_BatchNormalized')(Attention_Dot)
        Attention_Dot=Activation('relu',name=GeneSet+'_RELU')(Attention_Dot)
        GeneSet_Model.append(Attention_Dot)
        GeneSet_Input.append(Gene_Input)

    Drug_effected_Model_for_Attention=GeneSet_Model.copy()
    
    
    Drug_Dense_Sample=Dense(int(len(GeneSet_Dic_withoutNA)/16)+1,dtype='float32',name='Sample_Drug_Dense',kernel_initializer=initializer)(Drug_Dense_New2)
    Drug_Dense_Sample=BatchNormalization(name=GeneSet+'Sample_Drug_Batch')(Drug_Dense_Sample)
    Drug_Dense_Sample=Activation('relu', name='Sample_Drug_ReLU')(Drug_Dense_Sample)    #Drug feature to attention layer
    Drug_effected_Model_for_Attention.append(Drug_Dense_Sample)
    
    GeneSet_Concat=concatenate(GeneSet_Model,axis=1, name='GeneSet_Concatenate')
    Drug_effected_Concat=concatenate(Drug_effected_Model_for_Attention,axis=1, name='Drug_effected_Concatenate')
    Sample_Attention=Dense(len(GeneSet_Dic_withoutNA.keys()),activation='tanh', name='Sample_Attention_Dense',kernel_initializer=initializer)(Drug_effected_Concat)
    Sample_Attention=Activation(activation='softmax', name='Sample_Attention_Softmax')(Sample_Attention)
    Sample_Multiplied=multiply([GeneSet_Concat,Sample_Attention], name='Sample_Attention_Multiplied')
    Sample_Multiplied=BatchNormalization(name='Sample_Attention_BatchNormalized')(Sample_Multiplied)
    Sample_Multiplied=Activation('relu',name='Sample_Attention_Relu')(Sample_Multiplied)
    
    Input_for_model=[]
    for GeneSet_f in GeneSet_Input:
        Input_for_model.append(GeneSet_f)
    Input_for_model.append(Drug_Input)
    
    Dose_Input=Input((1,), dtype='float32', name='Dose_Input')
    Input_for_model.append(Dose_Input)

    Total_model=[Sample_Multiplied,Drug_Dense2]
    Model_Concat=concatenate(Total_model,axis=1, name='Total_Concatenate')
    Concated=Dense(128, name='Total_Dense')(Model_Concat)
    Concated=BatchNormalization(name='Total_BatchNormalized')(Concated)
    Concated=Activation(activation='relu', name='Total_RELU')(Concated)
    
    Final=Dense(32, name='Output_Dense1',kernel_initializer=initializer)(Concated)
    Final=BatchNormalization()(Final)
    Final=Activation(activation='relu',name='Output_RELU')(Final)
    Final=Dense(8,name='Output_Dense2',kernel_initializer=initializer)(Final)
    Final=BatchNormalization()(Final)
    Final=Activation(activation='relu',name='Output_RELU2')(Final)
    Final=Dense(2, name='Output_Dense3',kernel_initializer=initializer)(Final)    
    Final=BatchNormalization()(Final)
    Final=Activation(activation='relu',name='Output_RELU3')(Final)
    
    Final_y_max=Dense(1, name='y_max',kernel_initializer=initializer)(Final)
    Final_y_min=Dense(1, name='y_min',kernel_initializer=initializer)(Final)
    Final_slope=Dense(1, name='slope',kernel_initializer=initializer)(Final)
    Final_IC50=Dense(1, name='IC50',kernel_initializer=initializer)(Final)

    Final_1=subtract([Dose_Input,Final_IC50],name='Final_1')
    Final_2=multiply([Final_slope,Final_1],name='Final_2')
    Final_negative=Lambda(lambda x:-1*x)(Final_2)
    Final_Sigmoid=Activation(activation='sigmoid',name='Final_Sigmoid')(Final_negative)
    Final_scale=subtract([Final_y_max,Final_y_min],name='Final_scale')
    Final_scale=Activation(activation='relu',name='Final_scale_activation')(Final_scale)
    Final_3=multiply([Final_scale,Final_Sigmoid],name='Final_3')
    Final_4=add([Final_3,Final_y_min],name='Final_4')
    model=Model(inputs=Input_for_model,outputs=Final_4)

    return model

# %%
NCI60_model=Making_Model()
# Out:
# WARNING:tensorflow:From /tmp/ipykernel_51711/3143332237.py:6: The name tf.keras.initializers.he_uniform is deprecated. Please use tf.compat.v1.keras.initializers.he_uniform instead.
#
# WARNING:tensorflow:From /usr/local/lib/python3.7/site-packages/keras/backend/tensorflow_backend.py:517: The name tf.placeholder is deprecated. Please use tf.compat.v1.placeholder instead.
#
# WARNING:tensorflow:From /usr/local/lib/python3.7/site-packages/keras/backend/tensorflow_backend.py:4138: The name tf.random_uniform is deprecated. Please use tf.random.uniform instead.

# %%
NCI60_model.load_weights('/DAS_Storage4/ijjin/Study_2/220921_Final/Single/NCI60_March22/Result/221107_Full/221107_Full.hdf5')
# Out:
# WARNING:tensorflow:From /usr/local/lib/python3.7/site-packages/keras/backend/tensorflow_backend.py:174: The name tf.get_default_session is deprecated. Please use tf.compat.v1.get_default_session instead.
#
# WARNING:tensorflow:From /usr/local/lib/python3.7/site-packages/keras/backend/tensorflow_backend.py:190: The name tf.global_variables is deprecated. Please use tf.compat.v1.global_variables instead.
#
# WARNING:tensorflow:From /usr/local/lib/python3.7/site-packages/keras/backend/tensorflow_backend.py:199: The name tf.is_variable_initialized is deprecated. Please use tf.compat.v1.is_variable_initialized instead.
#
# WARNING:tensorflow:From /usr/local/lib/python3.7/site-packages/keras/backend/tensorflow_backend.py:206: The name tf.variables_initializer is deprecated. Please use tf.compat.v1.variables_initializer instead.

# %%
for layer in NCI60_model.layers:
    if isinstance(layer, BatchNormalization):
        layer.trainable = True
    else:
        layer.trainable = False
        
for layer in NCI60_model.layers:
    if layer.trainable==True:
        print(layer)
        print(layer.trainable)
# Out:
# <keras.layers.normalization.BatchNormalization object at 0x7f9b91e45ed0>
# True
# <keras.layers.normalization.BatchNormalization object at 0x7f9b88241890>
# True
# <keras.layers.normalization.BatchNormalization object at 0x7f9b9210acd0>
# True
# <keras.layers.normalization.BatchNormalization object at 0x7f9b8ddf0b50>
# True
# <keras.layers.normalization.BatchNormalization object at 0x7f9b8dc318d0>
# True
# <keras.layers.normalization.BatchNormalization object at 0x7f9b8d4ba850>
# True
# <keras.layers.normalization.BatchNormalization object at 0x7f9b8ccf5a50>
# True
# <keras.layers.normalization.BatchNormalization object at 0x7f9b8c52a450>
# True
# <keras.layers.normalization.BatchNormalization object at 0x7f9b89acc3d0>
# True
# <keras.layers.normalization.BatchNormalization object at 0x7f9b7d823290>
# True
# <keras.layers.normalization.BatchNormalization object at 0x7f9b766a8ed0>
# True
# <keras.layers.normalization.BatchNormalization object at 0x7f9b715a8590>
# True
# <keras.layers.normalization.BatchNormalization object at 0x7f9b8d37b710>
# True
# <keras.layers.normalization.BatchNormalization object at 0x7f9b87a455d0>
# True
# <keras.layers.normalization.BatchNormalization object at 0x7f9b8c435290>
# True
# <keras.layers.normalization.BatchNormalization object at 0x7f9b8c48ac90>
# True
# <keras.layers.normalization.BatchNormalization object at 0x7f9b8d511850>
# True
# <keras.layers.normalization.BatchNormalization object at 0x7f9b810c1910>
# True
# <keras.layers.normalization.BatchNormalization object at 0x7f9b800bb8d0>
# True
# <keras.layers.normalization.BatchNormalization object at 0x7f9b8dd9df10>
# True
# <keras.layers.normalization.BatchNormalization object at 0x7f9b8b817990>
# True
# <keras.layers.normalization.BatchNormalization object at 0x7f9b8b7e3a90>
# True
# <keras.layers.normalization.BatchNormalization object at 0x7f9b8b6ccad0>
# True
# <keras.layers.normalization.BatchNormalization object at 0x7f9b8bd78fd0>
# True
# <keras.layers.normalization.BatchNormalization object at 0x7f9b8bd06c10>
# True
# <keras.layers.normalization.BatchNormalization object at 0x7f9b8b6aba50>
# True
# <keras.layers.normalization.BatchNormalization object at 0x7f9b8b5d4d50>
# True
# <keras.layers.normalization.BatchNormalization object at 0x7f9b8b56db90>
# True
# <keras.layers.normalization.BatchNormalization object at 0x7f9b8b4a1cd0>
# True
# <keras.layers.normalization.BatchNormalization object at 0x7f9b8b3ebe90>
# True
# <keras.layers.normalization.BatchNormalization object at 0x7f9b8b2d88d0>
# True
# <keras.layers.normalization.BatchNormalization object at 0x7f9b8b206950>
# True
# <keras.layers.normalization.BatchNormalization object at 0x7f9b8b13ff10>
# True
# <keras.layers.normalization.BatchNormalization object at 0x7f9b8b0ee9d0>
# True
# <keras.layers.normalization.BatchNormalization object at 0x7f9b8b028fd0>
# True
# <keras.layers.normalization.BatchNormalization object at 0x7f9b8afb4d10>
# True
# <keras.layers.normalization.BatchNormalization object at 0x7f9b8ae8f950>
# True
# <keras.layers.normalization.BatchNormalization object at 0x7f9b8adb9c50>
# True
# <keras.layers.normalization.BatchNormalization object at 0x7f9b8ad73a50>
# True
# <keras.layers.normalization.BatchNormalization object at 0x7f9b8ac9dd50>
# True
# <keras.layers.normalization.BatchNormalization object at 0x7f9b8abb6b90>
# True
# <keras.layers.normalization.BatchNormalization object at 0x7f9b8ab6bc50>
# True
# <keras.layers.normalization.BatchNormalization object at 0x7f9b8a9f7e90>
# True
# <keras.layers.normalization.BatchNormalization object at 0x7f9b8a9ad890>
# True
# <keras.layers.normalization.BatchNormalization object at 0x7f9b8a8dafd0>
# True
# <keras.layers.normalization.BatchNormalization object at 0x7f9b8a80de90>
# True
# <keras.layers.normalization.BatchNormalization object at 0x7f9b8a73a950>
# True
# <keras.layers.normalization.BatchNormalization object at 0x7f9b8a692a50>
# True
# <keras.layers.normalization.BatchNormalization object at 0x7f9b8a620a90>
# True
# <keras.layers.normalization.BatchNormalization object at 0x7f9b8a571b90>
# True
# <keras.layers.normalization.BatchNormalization object at 0x7f9b8a481bd0>
# True
# <keras.layers.normalization.BatchNormalization object at 0x7f9b8a3b9290>
# True
# <keras.layers.normalization.BatchNormalization object at 0x7f9b8a361d10>
# True
# <keras.layers.normalization.BatchNormalization object at 0x7f9b8a23cb50>
# True
# <keras.layers.normalization.BatchNormalization object at 0x7f9b8a176c10>
# True
# <keras.layers.normalization.BatchNormalization object at 0x7f9b8a0c3690>
# True
# <keras.layers.normalization.BatchNormalization object at 0x7f9b89ffa890>
# True
# <keras.layers.normalization.BatchNormalization object at 0x7f9b89fab910>
# True
# <keras.layers.normalization.BatchNormalization object at 0x7f9b89edde50>
# True
# <keras.layers.normalization.BatchNormalization object at 0x7f9b89e0a910>
# True
# <keras.layers.normalization.BatchNormalization object at 0x7f9b89d3f610>
# True
# <keras.layers.normalization.BatchNormalization object at 0x7f9b89ccfbd0>
# True
# <keras.layers.normalization.BatchNormalization object at 0x7f9b89bbeb50>
# True
# <keras.layers.normalization.BatchNormalization object at 0x7f9b89b4bb90>
# True
# <keras.layers.normalization.BatchNormalization object at 0x7f9b89a49250>
# True
# <keras.layers.normalization.BatchNormalization object at 0x7f9b899f2cd0>
# True
# <keras.layers.normalization.BatchNormalization object at 0x7f9b8990ab10>
# True
# <keras.layers.normalization.BatchNormalization object at 0x7f9b8983fc90>
# True
# <keras.layers.normalization.BatchNormalization object at 0x7f9b8978a650>
# True
# <keras.layers.normalization.BatchNormalization object at 0x7f9b89726ed0>
# True
# <keras.layers.normalization.BatchNormalization object at 0x7f9b89673fd0>
# True
# <keras.layers.normalization.BatchNormalization object at 0x7f9b895ace90>
# True
# <keras.layers.normalization.BatchNormalization object at 0x7f9b894d9950>
# True
# <keras.layers.normalization.BatchNormalization object at 0x7f9b8942ea50>
# True
# <keras.layers.normalization.BatchNormalization object at 0x7f9b8933ca90>
# True
# <keras.layers.normalization.BatchNormalization object at 0x7f9b8924fb90>
# True
# <keras.layers.normalization.BatchNormalization object at 0x7f9b891dabd0>
# True
# <keras.layers.normalization.BatchNormalization object at 0x7f9b89115290>
# True
# <keras.layers.normalization.BatchNormalization object at 0x7f9b8903ed10>
# True
# <keras.layers.normalization.BatchNormalization object at 0x7f9b88fd7b50>
# True
# <keras.layers.normalization.BatchNormalization object at 0x7f9b88f0cc10>
# True
# <keras.layers.normalization.BatchNormalization object at 0x7f9b88e58690>
# True
# <keras.layers.normalization.BatchNormalization object at 0x7f9b88d8d890>
# True
# <keras.layers.normalization.BatchNormalization object at 0x7f9b88cb7910>
# True
# <keras.layers.normalization.BatchNormalization object at 0x7f9b88c6fed0>
# True
# <keras.layers.normalization.BatchNormalization object at 0x7f9b88b9e990>
# True
# <keras.layers.normalization.BatchNormalization object at 0x7f9b88af3a90>
# True
# <keras.layers.normalization.BatchNormalization object at 0x7f9b889c5ad0>
# True
# <keras.layers.normalization.BatchNormalization object at 0x7f9b88918fd0>
# True
# <keras.layers.normalization.BatchNormalization object at 0x7f9b888a2c10>
# True
# <keras.layers.normalization.BatchNormalization object at 0x7f9b887dda50>
# True
# <keras.layers.normalization.BatchNormalization object at 0x7f9b88702d50>
# True
# <keras.layers.normalization.BatchNormalization object at 0x7f9b88699b90>
# True
# <keras.layers.normalization.BatchNormalization object at 0x7f9b885cbc50>
# True
# <keras.layers.normalization.BatchNormalization object at 0x7f9b88510e90>
# True
# <keras.layers.normalization.BatchNormalization object at 0x7f9b884428d0>
# True
# <keras.layers.normalization.BatchNormalization object at 0x7f9b883ef950>
# True
# <keras.layers.normalization.BatchNormalization object at 0x7f9b88323f10>
# True
# <keras.layers.normalization.BatchNormalization object at 0x7f9b881ce9d0>
# True
# <keras.layers.normalization.BatchNormalization object at 0x7f9b8810afd0>
# True
# <keras.layers.normalization.BatchNormalization object at 0x7f9b88094d10>
# True
# <keras.layers.normalization.BatchNormalization object at 0x7f9b87fea950>
# True
# <keras.layers.normalization.BatchNormalization object at 0x7f9b87f11c50>
# True
# <keras.layers.normalization.BatchNormalization object at 0x7f9b87e4ca90>
# True
# <keras.layers.normalization.BatchNormalization object at 0x7f9b87de1b50>
# True
# <keras.layers.normalization.BatchNormalization object at 0x7f9b87d12bd0>
# True
# <keras.layers.normalization.BatchNormalization object at 0x7f9b87c48c90>
# True
# <keras.layers.normalization.BatchNormalization object at 0x7f9b87b92b50>
# True
# <keras.layers.normalization.BatchNormalization object at 0x7f9b87ac7910>
# True
# <keras.layers.normalization.BatchNormalization object at 0x7f9b87a328d0>
# True
# <keras.layers.normalization.BatchNormalization object at 0x7f9b879605d0>
# True
# <keras.layers.normalization.BatchNormalization object at 0x7f9b87892a10>
# True
# <keras.layers.normalization.BatchNormalization object at 0x7f9b877e7b10>
# True
# <keras.layers.normalization.BatchNormalization object at 0x7f9b87774b50>
# True
# <keras.layers.normalization.BatchNormalization object at 0x7f9b876ae950>
# True
# <keras.layers.normalization.BatchNormalization object at 0x7f9b875d2c50>
# True
# <keras.layers.normalization.BatchNormalization object at 0x7f9b87509a90>
# True
# <keras.layers.normalization.BatchNormalization object at 0x7f9b8749dc10>
# True
# <keras.layers.normalization.BatchNormalization object at 0x7f9b873cdbd0>
# True
# <keras.layers.normalization.BatchNormalization object at 0x7f9b87301e90>
# True
# <keras.layers.normalization.BatchNormalization object at 0x7f9b8720c850>
# True
# <keras.layers.normalization.BatchNormalization object at 0x7f9b8713e910>
# True
# <keras.layers.normalization.BatchNormalization object at 0x7f9b870ec8d0>
# True
# <keras.layers.normalization.BatchNormalization object at 0x7f9b870205d0>
# True
# <keras.layers.normalization.BatchNormalization object at 0x7f9b86f4da10>
# True
# <keras.layers.normalization.BatchNormalization object at 0x7f9b86e9db10>
# True
# <keras.layers.normalization.BatchNormalization object at 0x7f9b86e2cb50>
# True
# <keras.layers.normalization.BatchNormalization object at 0x7f9b86d65210>
# True
# <keras.layers.normalization.BatchNormalization object at 0x7f9b86c8ec90>
# True
# <keras.layers.normalization.BatchNormalization object at 0x7f9b86c25ad0>
# True
# <keras.layers.normalization.BatchNormalization object at 0x7f9b86b59c50>
# True
# <keras.layers.normalization.BatchNormalization object at 0x7f9b86a84c10>
# True
# <keras.layers.normalization.BatchNormalization object at 0x7f9b86980e90>
# True
# <keras.layers.normalization.BatchNormalization object at 0x7f9b868c6ed0>
# True
# <keras.layers.normalization.BatchNormalization object at 0x7f9b867fae50>
# True
# <keras.layers.normalization.BatchNormalization object at 0x7f9b867ae910>
# True
# <keras.layers.normalization.BatchNormalization object at 0x7f9b866e3610>
# True
# <keras.layers.normalization.BatchNormalization object at 0x7f9b86675bd0>
# True
# <keras.layers.normalization.BatchNormalization object at 0x7f9b86567b50>
# True
# <keras.layers.normalization.BatchNormalization object at 0x7f9b86476b90>
# True
# <keras.layers.normalization.BatchNormalization object at 0x7f9b86435250>
# True
# <keras.layers.normalization.BatchNormalization object at 0x7f9b8635fcd0>
# True
# <keras.layers.normalization.BatchNormalization object at 0x7f9b8627ab10>
# True
# <keras.layers.normalization.BatchNormalization object at 0x7f9b861efc90>
# True
# <keras.layers.normalization.BatchNormalization object at 0x7f9b860ba650>
# True
# <keras.layers.normalization.BatchNormalization object at 0x7f9b86059ed0>
# True
# <keras.layers.normalization.BatchNormalization object at 0x7f9b85fa1fd0>
# True
# <keras.layers.normalization.BatchNormalization object at 0x7f9b85ed7e90>
# True
# <keras.layers.normalization.BatchNormalization object at 0x7f9b85e02950>
# True
# <keras.layers.normalization.BatchNormalization object at 0x7f9b85d55a50>
# True
# <keras.layers.normalization.BatchNormalization object at 0x7f9b85ce8a90>
# True
# <keras.layers.normalization.BatchNormalization object at 0x7f9b85bbab90>
# True
# <keras.layers.normalization.BatchNormalization object at 0x7f9b85b48bd0>
# True
# <keras.layers.normalization.BatchNormalization object at 0x7f9b85a85290>
# True
# <keras.layers.normalization.BatchNormalization object at 0x7f9b85a2cd10>
# True
# <keras.layers.normalization.BatchNormalization object at 0x7f9b85906b50>
# True
# <keras.layers.normalization.BatchNormalization object at 0x7f9b8583ccd0>
# True
# <keras.layers.normalization.BatchNormalization object at 0x7f9b85782690>
# True
# <keras.layers.normalization.BatchNormalization object at 0x7f9b85734890>
# True
# <keras.layers.normalization.BatchNormalization object at 0x7f9b8566ac10>
# True
# <keras.layers.normalization.BatchNormalization object at 0x7f9b855a2ed0>
# True
# <keras.layers.normalization.BatchNormalization object at 0x7f9b854cf990>
# True
# <keras.layers.normalization.BatchNormalization object at 0x7f9b85423a90>
# True
# <keras.layers.normalization.BatchNormalization object at 0x7f9b853b1ad0>
# True
# <keras.layers.normalization.BatchNormalization object at 0x7f9b85283fd0>
# True
# <keras.layers.normalization.BatchNormalization object at 0x7f9b8520fc10>
# True
# <keras.layers.normalization.BatchNormalization object at 0x7f9b8510ca50>
# True
# <keras.layers.normalization.BatchNormalization object at 0x7f9b85036d50>
# True
# <keras.layers.normalization.BatchNormalization object at 0x7f9b84fd2b90>
# True
# <keras.layers.normalization.BatchNormalization object at 0x7f9b84f07c50>
# True
# <keras.layers.normalization.BatchNormalization object at 0x7f9b84e4de90>
# True
# <keras.layers.normalization.BatchNormalization object at 0x7f9b84d7f8d0>
# True
# <keras.layers.normalization.BatchNormalization object at 0x7f9b84d2b950>
# True
# <keras.layers.normalization.BatchNormalization object at 0x7f9b84c5df10>
# True
# <keras.layers.normalization.BatchNormalization object at 0x7f9b84befbd0>
# True
# <keras.layers.normalization.BatchNormalization object at 0x7f9b84ad9b50>
# True
# <keras.layers.normalization.BatchNormalization object at 0x7f9b84a65b90>
# True
# <keras.layers.normalization.BatchNormalization object at 0x7f9b8495e250>
# True
# <keras.layers.normalization.BatchNormalization object at 0x7f9b84884cd0>
# True
# <keras.layers.normalization.BatchNormalization object at 0x7f9b8481ab10>
# True
# <keras.layers.normalization.BatchNormalization object at 0x7f9b8474fbd0>
# True
# <keras.layers.normalization.BatchNormalization object at 0x7f9b84695650>
# True
# <keras.layers.normalization.BatchNormalization object at 0x7f9b8462fed0>
# True
# <keras.layers.normalization.BatchNormalization object at 0x7f9b84575fd0>
# True
# <keras.layers.normalization.BatchNormalization object at 0x7f9b844aaf10>
# True
# <keras.layers.normalization.BatchNormalization object at 0x7f9b843d59d0>
# True
# <keras.layers.normalization.BatchNormalization object at 0x7f9b84310fd0>
# True
# <keras.layers.normalization.BatchNormalization object at 0x7f9b8429cd10>
# True
# <keras.layers.normalization.BatchNormalization object at 0x7f9b8e41ad50>
# True
# <keras.layers.normalization.BatchNormalization object at 0x7f9b8dca0c90>
# True
# <keras.layers.normalization.BatchNormalization object at 0x7f9b8d515b90>
# True
# <keras.layers.normalization.BatchNormalization object at 0x7f9b8d4187d0>
# True
# <keras.layers.normalization.BatchNormalization object at 0x7f9b8cc577d0>
# True
# <keras.layers.normalization.BatchNormalization object at 0x7f9b8c5167d0>
# True
# <keras.layers.normalization.BatchNormalization object at 0x7f9b81911b10>
# True
# <keras.layers.normalization.BatchNormalization object at 0x7f9b7a79e510>
# True
# <keras.layers.normalization.BatchNormalization object at 0x7f9b71dda8d0>
# True
# <keras.layers.normalization.BatchNormalization object at 0x7f9b6f512290>
# True
# <keras.layers.normalization.BatchNormalization object at 0x7f9b8bb40d10>
# True
# <keras.layers.normalization.BatchNormalization object at 0x7f9b851b6110>
# True
# <keras.layers.normalization.BatchNormalization object at 0x7f9b8c55a8d0>
# True
# <keras.layers.normalization.BatchNormalization object at 0x7f9b8e437b50>
# True
# <keras.layers.normalization.BatchNormalization object at 0x7f9b8c4c0390>
# True
# <keras.layers.normalization.BatchNormalization object at 0x7f9b8cc49150>
# True
# <keras.layers.normalization.BatchNormalization object at 0x7f9b908694d0>
# True
# <keras.layers.normalization.BatchNormalization object at 0x7f9b8bbdb210>
# True
# <keras.layers.normalization.BatchNormalization object at 0x7f9b8b701590>
# True
# <keras.layers.normalization.BatchNormalization object at 0x7f9b8b758b10>
# True
# <keras.layers.normalization.BatchNormalization object at 0x7f9b8bc3b750>
# True
# <keras.layers.normalization.BatchNormalization object at 0x7f9b8bd2cf50>
# True
# <keras.layers.normalization.BatchNormalization object at 0x7f9b8bc5fe90>
# True
# <keras.layers.normalization.BatchNormalization object at 0x7f9b8b5fb950>
# True
# <keras.layers.normalization.BatchNormalization object at 0x7f9b8b5ae950>
# True
# <keras.layers.normalization.BatchNormalization object at 0x7f9b8b4e1890>
# True
# <keras.layers.normalization.BatchNormalization object at 0x7f9b8b40ea90>
# True
# <keras.layers.normalization.BatchNormalization object at 0x7f9b8b343350>
# True
# <keras.layers.normalization.BatchNormalization object at 0x7f9b8b2acbd0>
# True
# <keras.layers.normalization.BatchNormalization object at 0x7f9b8b1e2490>
# True
# <keras.layers.normalization.BatchNormalization object at 0x7f9b8b0bc250>
# True
# <keras.layers.normalization.BatchNormalization object at 0x7f9b8b0475d0>
# True
# <keras.layers.normalization.BatchNormalization object at 0x7f9b8aff5ad0>
# True
# <keras.layers.normalization.BatchNormalization object at 0x7f9b8af2dd90>
# True
# <keras.layers.normalization.BatchNormalization object at 0x7f9b8ae60850>
# True
# <keras.layers.normalization.BatchNormalization object at 0x7f9b8ad93e90>
# True
# <keras.layers.normalization.BatchNormalization object at 0x7f9b8acc3950>
# True
# <keras.layers.normalization.BatchNormalization object at 0x7f9b8abf8950>
# True
# <keras.layers.normalization.BatchNormalization object at 0x7f9b8abaa890>
# True
# <keras.layers.normalization.BatchNormalization object at 0x7f9b8aa9ba90>
# True
# <keras.layers.normalization.BatchNormalization object at 0x7f9b8a9d0310>
# True
# <keras.layers.normalization.BatchNormalization object at 0x7f9b8a8fdb90>
# True
# <keras.layers.normalization.BatchNormalization object at 0x7f9b8a8b4410>
# True
# <keras.layers.normalization.BatchNormalization object at 0x7f9b8a7871d0>
# True
# <keras.layers.normalization.BatchNormalization object at 0x7f9b8a714550>
# True
# <keras.layers.normalization.BatchNormalization object at 0x7f9b8a644fd0>
# True
# <keras.layers.normalization.BatchNormalization object at 0x7f9b8a578710>
# True
# <keras.layers.normalization.BatchNormalization object at 0x7f9b8a523ed0>
# True
# <keras.layers.normalization.BatchNormalization object at 0x7f9b8a45be50>
# True
# <keras.layers.normalization.BatchNormalization object at 0x7f9b8a387910>
# True
# <keras.layers.normalization.BatchNormalization object at 0x7f9b8a27e910>
# True
# <keras.layers.normalization.BatchNormalization object at 0x7f9b8a22ee90>
# True
# <keras.layers.normalization.BatchNormalization object at 0x7f9b8a167a50>
# True
# <keras.layers.normalization.BatchNormalization object at 0x7f9b8a09d310>
# True
# <keras.layers.normalization.BatchNormalization object at 0x7f9b89fd1b90>
# True
# <keras.layers.normalization.BatchNormalization object at 0x7f9b89f023d0>
# True
# <keras.layers.normalization.BatchNormalization object at 0x7f9b89e57190>
# True
# <keras.layers.normalization.BatchNormalization object at 0x7f9b89de6510>
# True
# <keras.layers.normalization.BatchNormalization object at 0x7f9b89cb92d0>
# True
# <keras.layers.normalization.BatchNormalization object at 0x7f9b89c44650>
# True
# <keras.layers.normalization.BatchNormalization object at 0x7f9b89bf1ed0>
# True
# <keras.layers.normalization.BatchNormalization object at 0x7f9b89b25e10>
# True
# <keras.layers.normalization.BatchNormalization object at 0x7f9b89a168d0>
# True
# <keras.layers.normalization.BatchNormalization object at 0x7f9b8994a8d0>
# True
# <keras.layers.normalization.BatchNormalization object at 0x7f9b89878a10>
# True
# <keras.layers.normalization.BatchNormalization object at 0x7f9b8982ca10>
# True
# <keras.layers.normalization.BatchNormalization object at 0x7f9b897662d0>
# True
# <keras.layers.normalization.BatchNormalization object at 0x7f9b89698b50>
# True
# <keras.layers.normalization.BatchNormalization object at 0x7f9b895cf410>
# True
# <keras.layers.normalization.BatchNormalization object at 0x7f9b895251d0>
# True
# <keras.layers.normalization.BatchNormalization object at 0x7f9b894ae550>
# True
# <keras.layers.normalization.BatchNormalization object at 0x7f9b893e3fd0>
# True
# <keras.layers.normalization.BatchNormalization object at 0x7f9b89316710>
# True
# <keras.layers.normalization.BatchNormalization object at 0x7f9b89204ed0>
# True
# <keras.layers.normalization.BatchNormalization object at 0x7f9b891b3e50>
# True
# <keras.layers.normalization.BatchNormalization object at 0x7f9b890e2910>
# True
# <keras.layers.normalization.BatchNormalization object at 0x7f9b89018910>
# True
# <keras.layers.normalization.BatchNormalization object at 0x7f9b88f45e90>
# True
# <keras.layers.normalization.BatchNormalization object at 0x7f9b88e7ca50>
# True
# <keras.layers.normalization.BatchNormalization object at 0x7f9b88e30310>
# True
# <keras.layers.normalization.BatchNormalization object at 0x7f9b88d60b90>
# True
# <keras.layers.normalization.BatchNormalization object at 0x7f9b88c8bed0>
# True
# <keras.layers.normalization.BatchNormalization object at 0x7f9b88bea210>
# True
# <keras.layers.normalization.BatchNormalization object at 0x7f9b88af7590>
# True
# <keras.layers.normalization.BatchNormalization object at 0x7f9b88a69b10>
# True
# <keras.layers.normalization.BatchNormalization object at 0x7f9b8899f750>
# True
# <keras.layers.normalization.BatchNormalization object at 0x7f9b888ccf50>
# True
# <keras.layers.normalization.BatchNormalization object at 0x7f9b887fce90>
# True
# <keras.layers.normalization.BatchNormalization object at 0x7f9b887a9950>
# True
# <keras.layers.normalization.BatchNormalization object at 0x7f9b886da950>
# True
# <keras.layers.normalization.BatchNormalization object at 0x7f9b8860c890>
# True
# <keras.layers.normalization.BatchNormalization object at 0x7f9b88537a90>
# True
# <keras.layers.normalization.BatchNormalization object at 0x7f9b884e6350>
# True
# <keras.layers.normalization.BatchNormalization object at 0x7f9b88414bd0>
# True
# <keras.layers.normalization.BatchNormalization object at 0x7f9b88349490>
# True
# <keras.layers.normalization.BatchNormalization object at 0x7f9b8821d250>
# True
# <keras.layers.normalization.BatchNormalization object at 0x7f9b881a95d0>
# True
# <keras.layers.normalization.BatchNormalization object at 0x7f9b880d77d0>
# True
# <keras.layers.normalization.BatchNormalization object at 0x7f9b88008450>
# True
# <keras.layers.normalization.BatchNormalization object at 0x7f9b87f37850>
# True
# <keras.layers.normalization.BatchNormalization object at 0x7f9b87eeced0>
# True
# <keras.layers.normalization.BatchNormalization object at 0x7f9b87e19990>
# True
# <keras.layers.normalization.BatchNormalization object at 0x7f9b87d4f990>
# True
# <keras.layers.normalization.BatchNormalization object at 0x7f9b87c868d0>
# True
# <keras.layers.normalization.BatchNormalization object at 0x7f9b87bb7b50>
# True
# <keras.layers.normalization.BatchNormalization object at 0x7f9b87b6c390>
# True
# <keras.layers.normalization.BatchNormalization object at 0x7f9b87a00150>
# True
# <keras.layers.normalization.BatchNormalization object at 0x7f9b8798a4d0>
# True
# <keras.layers.normalization.BatchNormalization object at 0x7f9b878e0290>
# True
# <keras.layers.normalization.BatchNormalization object at 0x7f9b8786f610>
# True
# <keras.layers.normalization.BatchNormalization object at 0x7f9b8779a810>
# True
# <keras.layers.normalization.BatchNormalization object at 0x7f9b876ccd90>
# True
# <keras.layers.normalization.BatchNormalization object at 0x7f9b875f9850>
# True
# <keras.layers.normalization.BatchNormalization object at 0x7f9b875abed0>
# True
# <keras.layers.normalization.BatchNormalization object at 0x7f9b874d6990>
# True
# <keras.layers.normalization.BatchNormalization object at 0x7f9b8740d990>
# True
# <keras.layers.normalization.BatchNormalization object at 0x7f9b873408d0>
# True
# <keras.layers.normalization.BatchNormalization object at 0x7f9b872f1b50>
# True
# <keras.layers.normalization.BatchNormalization object at 0x7f9b871e3390>
# True
# <keras.layers.normalization.BatchNormalization object at 0x7f9b870b9150>
# True
# <keras.layers.normalization.BatchNormalization object at 0x7f9b870464d0>
# True
# <keras.layers.normalization.BatchNormalization object at 0x7f9b86f99290>
# True
# <keras.layers.normalization.BatchNormalization object at 0x7f9b86f26610>
# True
# <keras.layers.normalization.BatchNormalization object at 0x7f9b86e52810>
# True
# <keras.layers.normalization.BatchNormalization object at 0x7f9b86d85dd0>
# True
# <keras.layers.normalization.BatchNormalization object at 0x7f9b86d34890>
# True
# <keras.layers.normalization.BatchNormalization object at 0x7f9b86c67f10>
# True
# <keras.layers.normalization.BatchNormalization object at 0x7f9b86b939d0>
# True
# <keras.layers.normalization.BatchNormalization object at 0x7f9b86ac29d0>
# True
# <keras.layers.normalization.BatchNormalization object at 0x7f9b86a75b90>
# True
# <keras.layers.normalization.BatchNormalization object at 0x7f9b8696cb10>
# True
# <keras.layers.normalization.BatchNormalization object at 0x7f9b868a13d0>
# True
# <keras.layers.normalization.BatchNormalization object at 0x7f9b8677a190>
# True
# <keras.layers.normalization.BatchNormalization object at 0x7f9b86709510>
# True
# <keras.layers.normalization.BatchNormalization object at 0x7f9b8665f2d0>
# True
# <keras.layers.normalization.BatchNormalization object at 0x7f9b865ec650>
# True
# <keras.layers.normalization.BatchNormalization object at 0x7f9b8651ced0>
# True
# <keras.layers.normalization.BatchNormalization object at 0x7f9b86452e10>
# True
# <keras.layers.normalization.BatchNormalization object at 0x7f9b863838d0>
# True
# <keras.layers.normalization.BatchNormalization object at 0x7f9b862bc8d0>
# True
# <keras.layers.normalization.BatchNormalization object at 0x7f9b86268a10>
# True
# <keras.layers.normalization.BatchNormalization object at 0x7f9b8615da10>
# True
# <keras.layers.normalization.BatchNormalization object at 0x7f9b860952d0>
# True
# <keras.layers.normalization.BatchNormalization object at 0x7f9b85fc7b50>
# True
# <keras.layers.normalization.BatchNormalization object at 0x7f9b85efc410>
# True
# <keras.layers.normalization.BatchNormalization object at 0x7f9b85e511d0>
# True
# <keras.layers.normalization.BatchNormalization object at 0x7f9b85ddb550>
# True
# <keras.layers.normalization.BatchNormalization object at 0x7f9b85d09fd0>
# True
# <keras.layers.normalization.BatchNormalization object at 0x7f9b85c43710>
# True
# <keras.layers.normalization.BatchNormalization object at 0x7f9b85beeed0>
# True
# <keras.layers.normalization.BatchNormalization object at 0x7f9b85b22e50>
# True
# <keras.layers.normalization.BatchNormalization object at 0x7f9b85a53910>
# True
# <keras.layers.normalization.BatchNormalization object at 0x7f9b85944910>
# True
# <keras.layers.normalization.BatchNormalization object at 0x7f9b858f5e90>
# True
# <keras.layers.normalization.BatchNormalization object at 0x7f9b8582aa50>
# True
# <keras.layers.normalization.BatchNormalization object at 0x7f9b8575a310>
# True
# <keras.layers.normalization.BatchNormalization object at 0x7f9b8568db90>
# True
# <keras.layers.normalization.BatchNormalization object at 0x7f9b855c0ed0>
# True
# <keras.layers.normalization.BatchNormalization object at 0x7f9b8551d210>
# True
# <keras.layers.normalization.BatchNormalization object at 0x7f9b854a8590>
# True
# <keras.layers.normalization.BatchNormalization object at 0x7f9b853d6b10>
# True
# <keras.layers.normalization.BatchNormalization object at 0x7f9b8530b750>
# True
# <keras.layers.normalization.BatchNormalization object at 0x7f9b85236f50>
# True
# <keras.layers.normalization.BatchNormalization object at 0x7f9b851a9e90>
# True
# <keras.layers.normalization.BatchNormalization object at 0x7f9b850da950>
# True
# <keras.layers.normalization.BatchNormalization object at 0x7f9b85013950>
# True
# <keras.layers.normalization.BatchNormalization object at 0x7f9b84f46890>
# True
# <keras.layers.normalization.BatchNormalization object at 0x7f9b84ef4a90>
# True
# <keras.layers.normalization.BatchNormalization object at 0x7f9b84e24350>
# True
# <keras.layers.normalization.BatchNormalization object at 0x7f9b84d51bd0>
# True
# <keras.layers.normalization.BatchNormalization object at 0x7f9b84c82490>
# True
# <keras.layers.normalization.BatchNormalization object at 0x7f9b84be7750>
# True
# <keras.layers.normalization.BatchNormalization object at 0x7f9b84b60650>
# True
# <keras.layers.normalization.BatchNormalization object at 0x7f9b84a8aed0>
# True
# <keras.layers.normalization.BatchNormalization object at 0x7f9b849bfe10>
# True
# <keras.layers.normalization.BatchNormalization object at 0x7f9b8492b8d0>
# True
# <keras.layers.normalization.BatchNormalization object at 0x7f9b8485c8d0>
# True
# <keras.layers.normalization.BatchNormalization object at 0x7f9b84787a10>
# True
# <keras.layers.normalization.BatchNormalization object at 0x7f9b846bca10>
# True
# <keras.layers.normalization.BatchNormalization object at 0x7f9b8466e2d0>
# True
# <keras.layers.normalization.BatchNormalization object at 0x7f9b8459db50>
# True
# <keras.layers.normalization.BatchNormalization object at 0x7f9b844807d0>
# True
# <keras.layers.normalization.BatchNormalization object at 0x7f9b84423250>
# True
# <keras.layers.normalization.BatchNormalization object at 0x7f9b843af5d0>
# True
# <keras.layers.normalization.BatchNormalization object at 0x7f9b842dbad0>
# True
# <keras.layers.normalization.BatchNormalization object at 0x7f9b84210d90>
# True
# <keras.layers.normalization.BatchNormalization object at 0x7f9b841cfb10>
# True
# <keras.layers.normalization.BatchNormalization object at 0x7f9b91fe74d0>
# True
# <keras.layers.normalization.BatchNormalization object at 0x7f9b840fc650>
# True
# <keras.layers.normalization.BatchNormalization object at 0x7f9b91f56850>
# True
# <keras.layers.normalization.BatchNormalization object at 0x7f9b840e3550>
# True
# <keras.layers.normalization.BatchNormalization object at 0x7f9b8403e1d0>
# True
# <keras.layers.normalization.BatchNormalization object at 0x7f9b84012f50>
# True
# <keras.layers.normalization.BatchNormalization object at 0x7f9b83fdca10>
# True

# %%
NCI60_model.compile(loss=aggregated_loss,optimizer=keras.optimizers.Adam(lr=0.01),metrics=[plcc_metric,'mean_squared_error'])
# Out:
# WARNING:tensorflow:From /usr/local/lib/python3.7/site-packages/keras/optimizers.py:790: The name tf.train.Optimizer is deprecated. Please use tf.compat.v1.train.Optimizer instead.

# %%
NCI60_model.evaluate(X_origin,NCI_ALMANAC_randomized.PERCENTGROWTH,batch_size=2048)
# Out:
# 2022-11-14 15:39:20.748130: I tensorflow/stream_executor/platform/default/dso_loader.cc:44] Successfully opened dynamic library libcublas.so.10.0
# 20987/20987 [==============================] - 18s 850us/step
# [0.22042313477699574, 0.8368354605169755, 0.057258594933991866]

# %%
from keras.callbacks import Callback, ReduceLROnPlateau, EarlyStopping

reduce_lr = ReduceLROnPlateau(monitor='val_loss', min_delta=0.0005, factor=0.1, patience=10, min_lr=0, verbose=1)
es = EarlyStopping(monitor='val_loss', mode='min', verbose=1, patience=20, min_delta=0.0005, restore_best_weights=True)

# %%
hist=NCI60_model.fit([df.iloc[training_Response_list] for df in X_origin],NCI_ALMANAC_randomized.iloc[training_Response_list].PERCENTGROWTH,validation_data=([df.iloc[validation_Response_list] for df in X_origin],NCI_ALMANAC_randomized.iloc[validation_Response_list].PERCENTGROWTH),batch_size=1024,epochs=2000,verbose=1,callbacks=[reduce_lr,es])
# Out:
# WARNING:tensorflow:From /usr/local/lib/python3.7/site-packages/tensorflow_core/python/ops/math_grad.py:1424: where (from tensorflow.python.ops.array_ops) is deprecated and will be removed in a future version.
# Instructions for updating:
# Use tf.where in 2.0, which has the same broadcast rule as np.where
# WARNING:tensorflow:From /usr/local/lib/python3.7/site-packages/keras/backend/tensorflow_backend.py:986: The name tf.assign_add is deprecated. Please use tf.compat.v1.assign_add instead.
#
# WARNING:tensorflow:From /usr/local/lib/python3.7/site-packages/keras/backend/tensorflow_backend.py:973: The name tf.assign is deprecated. Please use tf.compat.v1.assign instead.
#
# Train on 16790 samples, validate on 2099 samples
# Epoch 1/2000
# 16790/16790 [==============================] - 153s 9ms/step - loss: 0.3313 - plcc_metric: 0.7513 - mean_squared_error: 0.0826 - val_loss: 0.2930 - val_plcc_metric: 0.7813 - val_mean_squared_error: 0.0743
# Epoch 2/2000
# 16790/16790 [==============================] - 11s 668us/step - loss: 0.2694 - plcc_metric: 0.7967 - mean_squared_error: 0.0661 - val_loss: 0.2643 - val_plcc_metric: 0.8020 - val_mean_squared_error: 0.0663
# Epoch 3/2000
# 16790/16790 [==============================] - 12s 687us/step - loss: 0.2419 - plcc_metric: 0.8175 - mean_squared_error: 0.0594 - val_loss: 0.2423 - val_plcc_metric: 0.8187 - val_mean_squared_error: 0.0610
# Epoch 4/2000
# 16790/16790 [==============================] - 13s 774us/step - loss: 0.2204 - plcc_metric: 0.8337 - mean_squared_error: 0.0541 - val_loss: 0.2277 - val_plcc_metric: 0.8302 - val_mean_squared_error: 0.0579
# Epoch 5/2000
# 16790/16790 [==============================] - 12s 744us/step - loss: 0.2012 - plcc_metric: 0.8482 - mean_squared_error: 0.0494 - val_loss: 0.2168 - val_plcc_metric: 0.8396 - val_mean_squared_error: 0.0563
# Epoch 6/2000
# 16790/16790 [==============================] - 13s 772us/step - loss: 0.1846 - plcc_metric: 0.8608 - mean_squared_error: 0.0454 - val_loss: 0.2053 - val_plcc_metric: 0.8488 - val_mean_squared_error: 0.0541
# Epoch 7/2000
# 16790/16790 [==============================] - 14s 815us/step - loss: 0.1745 - plcc_metric: 0.8687 - mean_squared_error: 0.0432 - val_loss: 0.1973 - val_plcc_metric: 0.8553 - val_mean_squared_error: 0.0526
# Epoch 8/2000
# 16790/16790 [==============================] - 13s 760us/step - loss: 0.1663 - plcc_metric: 0.8750 - mean_squared_error: 0.0414 - val_loss: 0.1927 - val_plcc_metric: 0.8595 - val_mean_squared_error: 0.0522
# Epoch 9/2000
# 16790/16790 [==============================] - 13s 785us/step - loss: 0.1575 - plcc_metric: 0.8817 - mean_squared_error: 0.0392 - val_loss: 0.1803 - val_plcc_metric: 0.8669 - val_mean_squared_error: 0.0471
# Epoch 10/2000
# 16790/16790 [==============================] - 13s 800us/step - loss: 0.1523 - plcc_metric: 0.8858 - mean_squared_error: 0.0381 - val_loss: 0.1784 - val_plcc_metric: 0.8699 - val_mean_squared_error: 0.0483
# Epoch 11/2000
# 16790/16790 [==============================] - 13s 772us/step - loss: 0.1488 - plcc_metric: 0.8883 - mean_squared_error: 0.0371 - val_loss: 0.1686 - val_plcc_metric: 0.8768 - val_mean_squared_error: 0.0454
# Epoch 12/2000
# 16790/16790 [==============================] - 13s 803us/step - loss: 0.1432 - plcc_metric: 0.8925 - mean_squared_error: 0.0357 - val_loss: 0.1627 - val_plcc_metric: 0.8803 - val_mean_squared_error: 0.0430
# Epoch 13/2000
# 16790/16790 [==============================] - 13s 768us/step - loss: 0.1394 - plcc_metric: 0.8954 - mean_squared_error: 0.0348 - val_loss: 0.1556 - val_plcc_metric: 0.8855 - val_mean_squared_error: 0.0411
# Epoch 14/2000
# 16790/16790 [==============================] - 13s 786us/step - loss: 0.1361 - plcc_metric: 0.8979 - mean_squared_error: 0.0340 - val_loss: 0.1514 - val_plcc_metric: 0.8883 - val_mean_squared_error: 0.0397
# Epoch 15/2000
# 16790/16790 [==============================] - 13s 780us/step - loss: 0.1328 - plcc_metric: 0.9006 - mean_squared_error: 0.0335 - val_loss: 0.1472 - val_plcc_metric: 0.8914 - val_mean_squared_error: 0.0385
# Epoch 16/2000
# 16790/16790 [==============================] - 13s 745us/step - loss: 0.1276 - plcc_metric: 0.9044 - mean_squared_error: 0.0320 - val_loss: 0.1476 - val_plcc_metric: 0.8924 - val_mean_squared_error: 0.0400
# Epoch 17/2000
# 16790/16790 [==============================] - 13s 756us/step - loss: 0.1259 - plcc_metric: 0.9057 - mean_squared_error: 0.0316 - val_loss: 0.1416 - val_plcc_metric: 0.8956 - val_mean_squared_error: 0.0372
# Epoch 18/2000
# 16790/16790 [==============================] - 13s 772us/step - loss: 0.1251 - plcc_metric: 0.9063 - mean_squared_error: 0.0314 - val_loss: 0.1391 - val_plcc_metric: 0.8975 - val_mean_squared_error: 0.0366
# Epoch 19/2000
# 16790/16790 [==============================] - 13s 759us/step - loss: 0.1226 - plcc_metric: 0.9081 - mean_squared_error: 0.0308 - val_loss: 0.1375 - val_plcc_metric: 0.8991 - val_mean_squared_error: 0.0367
# Epoch 20/2000
# 16790/16790 [==============================] - 12s 740us/step - loss: 0.1201 - plcc_metric: 0.9101 - mean_squared_error: 0.0302 - val_loss: 0.1352 - val_plcc_metric: 0.9002 - val_mean_squared_error: 0.0354
# Epoch 21/2000
# 16790/16790 [==============================] - 12s 737us/step - loss: 0.1189 - plcc_metric: 0.9110 - mean_squared_error: 0.0299 - val_loss: 0.1340 - val_plcc_metric: 0.9013 - val_mean_squared_error: 0.0353
# Epoch 22/2000
# 16790/16790 [==============================] - 13s 763us/step - loss: 0.1173 - plcc_metric: 0.9123 - mean_squared_error: 0.0296 - val_loss: 0.1334 - val_plcc_metric: 0.9020 - val_mean_squared_error: 0.0354
# Epoch 23/2000
# 16790/16790 [==============================] - 13s 757us/step - loss: 0.1157 - plcc_metric: 0.9133 - mean_squared_error: 0.0290 - val_loss: 0.1309 - val_plcc_metric: 0.9035 - val_mean_squared_error: 0.0344
# Epoch 24/2000
# 16790/16790 [==============================] - 13s 750us/step - loss: 0.1142 - plcc_metric: 0.9146 - mean_squared_error: 0.0287 - val_loss: 0.1297 - val_plcc_metric: 0.9045 - val_mean_squared_error: 0.0342
# Epoch 25/2000
# 16790/16790 [==============================] - 12s 727us/step - loss: 0.1116 - plcc_metric: 0.9166 - mean_squared_error: 0.0281 - val_loss: 0.1278 - val_plcc_metric: 0.9058 - val_mean_squared_error: 0.0335
# Epoch 26/2000
# 16790/16790 [==============================] - 13s 745us/step - loss: 0.1134 - plcc_metric: 0.9152 - mean_squared_error: 0.0286 - val_loss: 0.1259 - val_plcc_metric: 0.9068 - val_mean_squared_error: 0.0327
# Epoch 27/2000
# 16790/16790 [==============================] - 12s 728us/step - loss: 0.1104 - plcc_metric: 0.9174 - mean_squared_error: 0.0279 - val_loss: 0.1269 - val_plcc_metric: 0.9067 - val_mean_squared_error: 0.0335
# Epoch 28/2000
# 16790/16790 [==============================] - 13s 776us/step - loss: 0.1103 - plcc_metric: 0.9175 - mean_squared_error: 0.0278 - val_loss: 0.1251 - val_plcc_metric: 0.9079 - val_mean_squared_error: 0.0330
# Epoch 29/2000
# 16790/16790 [==============================] - 13s 759us/step - loss: 0.1084 - plcc_metric: 0.9190 - mean_squared_error: 0.0274 - val_loss: 0.1234 - val_plcc_metric: 0.9086 - val_mean_squared_error: 0.0320
# Epoch 30/2000
# 16790/16790 [==============================] - 12s 736us/step - loss: 0.1097 - plcc_metric: 0.9182 - mean_squared_error: 0.0279 - val_loss: 0.1227 - val_plcc_metric: 0.9092 - val_mean_squared_error: 0.0319
# Epoch 31/2000
# 16790/16790 [==============================] - 13s 756us/step - loss: 0.1075 - plcc_metric: 0.9197 - mean_squared_error: 0.0272 - val_loss: 0.1224 - val_plcc_metric: 0.9098 - val_mean_squared_error: 0.0322
# Epoch 32/2000
# 16790/16790 [==============================] - 13s 749us/step - loss: 0.1066 - plcc_metric: 0.9204 - mean_squared_error: 0.0270 - val_loss: 0.1213 - val_plcc_metric: 0.9102 - val_mean_squared_error: 0.0315
# Epoch 33/2000
# 16790/16790 [==============================] - 13s 752us/step - loss: 0.1059 - plcc_metric: 0.9210 - mean_squared_error: 0.0269 - val_loss: 0.1201 - val_plcc_metric: 0.9115 - val_mean_squared_error: 0.0316
# Epoch 34/2000
# 16790/16790 [==============================] - 13s 748us/step - loss: 0.1051 - plcc_metric: 0.9214 - mean_squared_error: 0.0266 - val_loss: 0.1227 - val_plcc_metric: 0.9100 - val_mean_squared_error: 0.0327
# Epoch 35/2000
# 16790/16790 [==============================] - 12s 741us/step - loss: 0.1062 - plcc_metric: 0.9208 - mean_squared_error: 0.0270 - val_loss: 0.1217 - val_plcc_metric: 0.9105 - val_mean_squared_error: 0.0323
# Epoch 36/2000
# 16790/16790 [==============================] - 13s 751us/step - loss: 0.1044 - plcc_metric: 0.9222 - mean_squared_error: 0.0266 - val_loss: 0.1197 - val_plcc_metric: 0.9116 - val_mean_squared_error: 0.0313
# Epoch 37/2000
# 16790/16790 [==============================] - 13s 767us/step - loss: 0.1042 - plcc_metric: 0.9221 - mean_squared_error: 0.0262 - val_loss: 0.1182 - val_plcc_metric: 0.9128 - val_mean_squared_error: 0.0310
# Epoch 38/2000
# 16790/16790 [==============================] - 13s 776us/step - loss: 0.1026 - plcc_metric: 0.9234 - mean_squared_error: 0.0260 - val_loss: 0.1182 - val_plcc_metric: 0.9126 - val_mean_squared_error: 0.0308
# Epoch 39/2000
# 16790/16790 [==============================] - 13s 762us/step - loss: 0.1023 - plcc_metric: 0.9236 - mean_squared_error: 0.0259 - val_loss: 0.1171 - val_plcc_metric: 0.9134 - val_mean_squared_error: 0.0305
# Epoch 40/2000
# 16790/16790 [==============================] - 13s 772us/step - loss: 0.1021 - plcc_metric: 0.9239 - mean_squared_error: 0.0260 - val_loss: 0.1161 - val_plcc_metric: 0.9141 - val_mean_squared_error: 0.0301
# Epoch 41/2000
# 16790/16790 [==============================] - 12s 731us/step - loss: 0.1016 - plcc_metric: 0.9241 - mean_squared_error: 0.0257 - val_loss: 0.1164 - val_plcc_metric: 0.9139 - val_mean_squared_error: 0.0303
# Epoch 42/2000
# 16790/16790 [==============================] - 13s 756us/step - loss: 0.1003 - plcc_metric: 0.9252 - mean_squared_error: 0.0255 - val_loss: 0.1161 - val_plcc_metric: 0.9142 - val_mean_squared_error: 0.0303
# Epoch 43/2000
# 16790/16790 [==============================] - 13s 752us/step - loss: 0.1013 - plcc_metric: 0.9244 - mean_squared_error: 0.0256 - val_loss: 0.1156 - val_plcc_metric: 0.9148 - val_mean_squared_error: 0.0304
# Epoch 44/2000
# 16790/16790 [==============================] - 12s 737us/step - loss: 0.1001 - plcc_metric: 0.9253 - mean_squared_error: 0.0255 - val_loss: 0.1170 - val_plcc_metric: 0.9140 - val_mean_squared_error: 0.0310
# Epoch 45/2000
# 16790/16790 [==============================] - 13s 764us/step - loss: 0.0995 - plcc_metric: 0.9258 - mean_squared_error: 0.0253 - val_loss: 0.1136 - val_plcc_metric: 0.9159 - val_mean_squared_error: 0.0294
# Epoch 46/2000
# 16790/16790 [==============================] - 12s 737us/step - loss: 0.0984 - plcc_metric: 0.9266 - mean_squared_error: 0.0250 - val_loss: 0.1141 - val_plcc_metric: 0.9156 - val_mean_squared_error: 0.0297
# Epoch 47/2000
# 16790/16790 [==============================] - 13s 749us/step - loss: 0.0991 - plcc_metric: 0.9261 - mean_squared_error: 0.0252 - val_loss: 0.1139 - val_plcc_metric: 0.9157 - val_mean_squared_error: 0.0297
# Epoch 48/2000
# 16790/16790 [==============================] - 13s 758us/step - loss: 0.0984 - plcc_metric: 0.9266 - mean_squared_error: 0.0250 - val_loss: 0.1142 - val_plcc_metric: 0.9157 - val_mean_squared_error: 0.0299
# Epoch 49/2000
# 16790/16790 [==============================] - 12s 738us/step - loss: 0.0986 - plcc_metric: 0.9264 - mean_squared_error: 0.0250 - val_loss: 0.1127 - val_plcc_metric: 0.9166 - val_mean_squared_error: 0.0293
# Epoch 50/2000
# 16790/16790 [==============================] - 12s 738us/step - loss: 0.0991 - plcc_metric: 0.9260 - mean_squared_error: 0.0251 - val_loss: 0.1123 - val_plcc_metric: 0.9168 - val_mean_squared_error: 0.0291
# Epoch 51/2000
# 16790/16790 [==============================] - 12s 736us/step - loss: 0.0970 - plcc_metric: 0.9276 - mean_squared_error: 0.0246 - val_loss: 0.1117 - val_plcc_metric: 0.9174 - val_mean_squared_error: 0.0291
# Epoch 52/2000
# 16790/16790 [==============================] - 13s 745us/step - loss: 0.0970 - plcc_metric: 0.9277 - mean_squared_error: 0.0247 - val_loss: 0.1125 - val_plcc_metric: 0.9168 - val_mean_squared_error: 0.0292
# Epoch 53/2000
# 16790/16790 [==============================] - 12s 743us/step - loss: 0.0961 - plcc_metric: 0.9283 - mean_squared_error: 0.0244 - val_loss: 0.1135 - val_plcc_metric: 0.9164 - val_mean_squared_error: 0.0298
# Epoch 54/2000
# 16790/16790 [==============================] - 13s 763us/step - loss: 0.0964 - plcc_metric: 0.9283 - mean_squared_error: 0.0247 - val_loss: 0.1111 - val_plcc_metric: 0.9176 - val_mean_squared_error: 0.0287
# Epoch 55/2000
# 16790/16790 [==============================] - 12s 738us/step - loss: 0.0971 - plcc_metric: 0.9275 - mean_squared_error: 0.0246 - val_loss: 0.1124 - val_plcc_metric: 0.9170 - val_mean_squared_error: 0.0294
# Epoch 56/2000
# 16790/16790 [==============================] - 12s 738us/step - loss: 0.0963 - plcc_metric: 0.9282 - mean_squared_error: 0.0246 - val_loss: 0.1105 - val_plcc_metric: 0.9182 - val_mean_squared_error: 0.0287
# Epoch 57/2000
# 16790/16790 [==============================] - 13s 769us/step - loss: 0.0965 - plcc_metric: 0.9281 - mean_squared_error: 0.0245 - val_loss: 0.1108 - val_plcc_metric: 0.9179 - val_mean_squared_error: 0.0286
# Epoch 58/2000
# 16790/16790 [==============================] - 13s 751us/step - loss: 0.0951 - plcc_metric: 0.9292 - mean_squared_error: 0.0242 - val_loss: 0.1104 - val_plcc_metric: 0.9184 - val_mean_squared_error: 0.0288
# Epoch 59/2000
# 16790/16790 [==============================] - 13s 760us/step - loss: 0.0959 - plcc_metric: 0.9285 - mean_squared_error: 0.0244 - val_loss: 0.1119 - val_plcc_metric: 0.9175 - val_mean_squared_error: 0.0294
# Epoch 60/2000
# 16790/16790 [==============================] - 13s 760us/step - loss: 0.0948 - plcc_metric: 0.9294 - mean_squared_error: 0.0242 - val_loss: 0.1097 - val_plcc_metric: 0.9188 - val_mean_squared_error: 0.0286
# Epoch 61/2000
# 16790/16790 [==============================] - 13s 749us/step - loss: 0.0953 - plcc_metric: 0.9289 - mean_squared_error: 0.0242 - val_loss: 0.1111 - val_plcc_metric: 0.9180 - val_mean_squared_error: 0.0290
# Epoch 62/2000
# 16790/16790 [==============================] - 13s 764us/step - loss: 0.0949 - plcc_metric: 0.9292 - mean_squared_error: 0.0241 - val_loss: 0.1096 - val_plcc_metric: 0.9187 - val_mean_squared_error: 0.0283
# Epoch 63/2000
# 16790/16790 [==============================] - 13s 754us/step - loss: 0.0938 - plcc_metric: 0.9301 - mean_squared_error: 0.0238 - val_loss: 0.1091 - val_plcc_metric: 0.9193 - val_mean_squared_error: 0.0284
# Epoch 64/2000
# 16790/16790 [==============================] - 13s 760us/step - loss: 0.0950 - plcc_metric: 0.9293 - mean_squared_error: 0.0243 - val_loss: 0.1084 - val_plcc_metric: 0.9198 - val_mean_squared_error: 0.0282
# Epoch 65/2000
# 16790/16790 [==============================] - 12s 743us/step - loss: 0.0938 - plcc_metric: 0.9302 - mean_squared_error: 0.0240 - val_loss: 0.1096 - val_plcc_metric: 0.9188 - val_mean_squared_error: 0.0284
# Epoch 66/2000
# 16790/16790 [==============================] - 12s 735us/step - loss: 0.0945 - plcc_metric: 0.9295 - mean_squared_error: 0.0241 - val_loss: 0.1097 - val_plcc_metric: 0.9193 - val_mean_squared_error: 0.0290
# Epoch 67/2000
# 16790/16790 [==============================] - 12s 744us/step - loss: 0.0943 - plcc_metric: 0.9299 - mean_squared_error: 0.0242 - val_loss: 0.1095 - val_plcc_metric: 0.9189 - val_mean_squared_error: 0.0285
# Epoch 68/2000
# 16790/16790 [==============================] - 12s 740us/step - loss: 0.0933 - plcc_metric: 0.9305 - mean_squared_error: 0.0238 - val_loss: 0.1099 - val_plcc_metric: 0.9187 - val_mean_squared_error: 0.0286
# Epoch 69/2000
# 16790/16790 [==============================] - 13s 762us/step - loss: 0.0932 - plcc_metric: 0.9306 - mean_squared_error: 0.0238 - val_loss: 0.1093 - val_plcc_metric: 0.9191 - val_mean_squared_error: 0.0284
# Epoch 70/2000
# 16790/16790 [==============================] - 12s 742us/step - loss: 0.0925 - plcc_metric: 0.9310 - mean_squared_error: 0.0236 - val_loss: 0.1091 - val_plcc_metric: 0.9193 - val_mean_squared_error: 0.0284
# Epoch 71/2000
# 16790/16790 [==============================] - 13s 765us/step - loss: 0.0940 - plcc_metric: 0.9300 - mean_squared_error: 0.0240 - val_loss: 0.1091 - val_plcc_metric: 0.9193 - val_mean_squared_error: 0.0284
# Epoch 72/2000
# 16790/16790 [==============================] - 13s 749us/step - loss: 0.0925 - plcc_metric: 0.9312 - mean_squared_error: 0.0237 - val_loss: 0.1092 - val_plcc_metric: 0.9193 - val_mean_squared_error: 0.0285
# Epoch 73/2000
# 16790/16790 [==============================] - 13s 746us/step - loss: 0.0926 - plcc_metric: 0.9311 - mean_squared_error: 0.0237 - val_loss: 0.1083 - val_plcc_metric: 0.9197 - val_mean_squared_error: 0.0280
# Epoch 74/2000
# 16790/16790 [==============================] - 13s 775us/step - loss: 0.0917 - plcc_metric: 0.9315 - mean_squared_error: 0.0231 - val_loss: 0.1087 - val_plcc_metric: 0.9197 - val_mean_squared_error: 0.0283
#
# Epoch 00074: ReduceLROnPlateau reducing learning rate to 0.0009999999776482583.
# Epoch 75/2000
# 16790/16790 [==============================] - 12s 720us/step - loss: 0.0926 - plcc_metric: 0.9309 - mean_squared_error: 0.0235 - val_loss: 0.1084 - val_plcc_metric: 0.9198 - val_mean_squared_error: 0.0282
# Epoch 76/2000
# 16790/16790 [==============================] - 11s 684us/step - loss: 0.0920 - plcc_metric: 0.9314 - mean_squared_error: 0.0234 - val_loss: 0.1086 - val_plcc_metric: 0.9196 - val_mean_squared_error: 0.0282
# Epoch 77/2000
# 16790/16790 [==============================] - 12s 704us/step - loss: 0.0916 - plcc_metric: 0.9318 - mean_squared_error: 0.0234 - val_loss: 0.1087 - val_plcc_metric: 0.9195 - val_mean_squared_error: 0.0282
# Epoch 78/2000
# 16790/16790 [==============================] - 13s 765us/step - loss: 0.0908 - plcc_metric: 0.9324 - mean_squared_error: 0.0232 - val_loss: 0.1085 - val_plcc_metric: 0.9197 - val_mean_squared_error: 0.0282
# Epoch 79/2000
# 16790/16790 [==============================] - 12s 737us/step - loss: 0.0913 - plcc_metric: 0.9320 - mean_squared_error: 0.0233 - val_loss: 0.1084 - val_plcc_metric: 0.9197 - val_mean_squared_error: 0.0281
# Epoch 80/2000
# 16790/16790 [==============================] - 13s 746us/step - loss: 0.0913 - plcc_metric: 0.9319 - mean_squared_error: 0.0232 - val_loss: 0.1084 - val_plcc_metric: 0.9197 - val_mean_squared_error: 0.0282
# Epoch 81/2000
# 16790/16790 [==============================] - 12s 735us/step - loss: 0.0915 - plcc_metric: 0.9318 - mean_squared_error: 0.0233 - val_loss: 0.1085 - val_plcc_metric: 0.9197 - val_mean_squared_error: 0.0282
# Epoch 82/2000
# 16790/16790 [==============================] - 13s 779us/step - loss: 0.0906 - plcc_metric: 0.9325 - mean_squared_error: 0.0231 - val_loss: 0.1083 - val_plcc_metric: 0.9198 - val_mean_squared_error: 0.0281
# Epoch 83/2000
# 16790/16790 [==============================] - 13s 764us/step - loss: 0.0920 - plcc_metric: 0.9314 - mean_squared_error: 0.0235 - val_loss: 0.1082 - val_plcc_metric: 0.9199 - val_mean_squared_error: 0.0281
# Epoch 84/2000
# 16790/16790 [==============================] - 12s 739us/step - loss: 0.0917 - plcc_metric: 0.9317 - mean_squared_error: 0.0235 - val_loss: 0.1081 - val_plcc_metric: 0.9200 - val_mean_squared_error: 0.0281
#
# Epoch 00084: ReduceLROnPlateau reducing learning rate to 9.999999310821295e-05.
# Restoring model weights from the end of the best epoch
# Epoch 00084: early stopping

# %%
NCI_ALMANAC_randomized.iloc[training_Response_list].to_csv('/DAS_Storage4/ijjin/Study_2/220921_Final/Single/NCI_ALMANAC_mono/Result/221114_BatchNorm_Training/221114_training_df.csv')
NCI_ALMANAC_randomized.iloc[validation_Response_list].to_csv('/DAS_Storage4/ijjin/Study_2/220921_Final/Single/NCI_ALMANAC_mono/Result/221114_BatchNorm_Training/221114_validation_df.csv')
NCI_ALMANAC_randomized.iloc[test_Response_list].to_csv('/DAS_Storage4/ijjin/Study_2/220921_Final/Single/NCI_ALMANAC_mono/Result/221114_BatchNorm_Training/221114_test_df.csv')

# %%
pd.DataFrame(hist.history).to_csv('/DAS_Storage4/ijjin/Study_2/220921_Final/Single/NCI_ALMANAC_mono/Result/221114_BatchNorm_Training/221114_BatchNorm_Training.csv')

# %%
NCI60_model.save('/DAS_Storage4/ijjin/Study_2/220921_Final/Single/NCI_ALMANAC_mono/Result/221114_BatchNorm_Training/221114_BatchNorm_Training.hdf5')

# %%
for layer in NCI60_model.layers[-25:]:
    layer.trainable = True

# %%
NCI60_model.compile(loss=aggregated_loss,optimizer=keras.optimizers.Adam(lr=0.01),metrics=[plcc_metric,'mean_squared_error'])

# %%
NCI60_model.evaluate(X_origin,NCI_ALMANAC_randomized.PERCENTGROWTH,batch_size=2048)
# Out:
# 20987/20987 [==============================] - 32s 2ms/step
# [0.09287412680286845, 0.9310061738712243, 0.02388030240174564]

# %%
hist=NCI60_model.fit([df.iloc[training_Response_list] for df in X_origin],NCI_ALMANAC_randomized.iloc[training_Response_list].PERCENTGROWTH,validation_data=([df.iloc[validation_Response_list] for df in X_origin],NCI_ALMANAC_randomized.iloc[validation_Response_list].PERCENTGROWTH),batch_size=1024,epochs=2000,verbose=1,callbacks=[reduce_lr,es])
# Out:
# Train on 16790 samples, validate on 2099 samples
# Epoch 1/2000
# 16790/16790 [==============================] - 173s 10ms/step - loss: 0.0963 - plcc_metric: 0.9281 - mean_squared_error: 0.0245 - val_loss: 0.1078 - val_plcc_metric: 0.9211 - val_mean_squared_error: 0.0289
# Epoch 2/2000
# 16790/16790 [==============================] - 11s 632us/step - loss: 0.0923 - plcc_metric: 0.9318 - mean_squared_error: 0.0241 - val_loss: 0.1051 - val_plcc_metric: 0.9221 - val_mean_squared_error: 0.0272
# Epoch 3/2000
# 16790/16790 [==============================] - 10s 615us/step - loss: 0.0897 - plcc_metric: 0.9331 - mean_squared_error: 0.0229 - val_loss: 0.1049 - val_plcc_metric: 0.9226 - val_mean_squared_error: 0.0275
# Epoch 4/2000
# 16790/16790 [==============================] - 11s 667us/step - loss: 0.0876 - plcc_metric: 0.9350 - mean_squared_error: 0.0226 - val_loss: 0.1048 - val_plcc_metric: 0.9227 - val_mean_squared_error: 0.0275
# Epoch 5/2000
# 16790/16790 [==============================] - 10s 614us/step - loss: 0.0863 - plcc_metric: 0.9359 - mean_squared_error: 0.0223 - val_loss: 0.1047 - val_plcc_metric: 0.9233 - val_mean_squared_error: 0.0280
# Epoch 6/2000
# 16790/16790 [==============================] - 11s 659us/step - loss: 0.0846 - plcc_metric: 0.9374 - mean_squared_error: 0.0220 - val_loss: 0.1046 - val_plcc_metric: 0.9232 - val_mean_squared_error: 0.0278
# Epoch 7/2000
# 16790/16790 [==============================] - 10s 613us/step - loss: 0.0841 - plcc_metric: 0.9375 - mean_squared_error: 0.0216 - val_loss: 0.1043 - val_plcc_metric: 0.9234 - val_mean_squared_error: 0.0277
# Epoch 8/2000
# 16790/16790 [==============================] - 11s 669us/step - loss: 0.0811 - plcc_metric: 0.9397 - mean_squared_error: 0.0208 - val_loss: 0.1052 - val_plcc_metric: 0.9228 - val_mean_squared_error: 0.0279
# Epoch 9/2000
# 16790/16790 [==============================] - 10s 607us/step - loss: 0.0815 - plcc_metric: 0.9395 - mean_squared_error: 0.0209 - val_loss: 0.1040 - val_plcc_metric: 0.9232 - val_mean_squared_error: 0.0272
# Epoch 10/2000
# 16790/16790 [==============================] - 10s 603us/step - loss: 0.0805 - plcc_metric: 0.9402 - mean_squared_error: 0.0206 - val_loss: 0.1027 - val_plcc_metric: 0.9247 - val_mean_squared_error: 0.0274
# Epoch 11/2000
# 16790/16790 [==============================] - 11s 637us/step - loss: 0.0792 - plcc_metric: 0.9413 - mean_squared_error: 0.0205 - val_loss: 0.1033 - val_plcc_metric: 0.9241 - val_mean_squared_error: 0.0274
# Epoch 12/2000
# 16790/16790 [==============================] - 11s 668us/step - loss: 0.0763 - plcc_metric: 0.9433 - mean_squared_error: 0.0196 - val_loss: 0.1019 - val_plcc_metric: 0.9246 - val_mean_squared_error: 0.0264
# Epoch 13/2000
# 16790/16790 [==============================] - 10s 621us/step - loss: 0.0771 - plcc_metric: 0.9427 - mean_squared_error: 0.0197 - val_loss: 0.1024 - val_plcc_metric: 0.9246 - val_mean_squared_error: 0.0271
# Epoch 14/2000
# 16790/16790 [==============================] - 10s 620us/step - loss: 0.0771 - plcc_metric: 0.9428 - mean_squared_error: 0.0199 - val_loss: 0.1043 - val_plcc_metric: 0.9244 - val_mean_squared_error: 0.0287
# Epoch 15/2000
# 16790/16790 [==============================] - 11s 662us/step - loss: 0.0753 - plcc_metric: 0.9442 - mean_squared_error: 0.0195 - val_loss: 0.1010 - val_plcc_metric: 0.9252 - val_mean_squared_error: 0.0262
# Epoch 16/2000
# 16790/16790 [==============================] - 10s 625us/step - loss: 0.0751 - plcc_metric: 0.9442 - mean_squared_error: 0.0193 - val_loss: 0.1016 - val_plcc_metric: 0.9253 - val_mean_squared_error: 0.0269
# Epoch 17/2000
# 16790/16790 [==============================] - 11s 630us/step - loss: 0.0740 - plcc_metric: 0.9450 - mean_squared_error: 0.0190 - val_loss: 0.1007 - val_plcc_metric: 0.9257 - val_mean_squared_error: 0.0264
# Epoch 18/2000
# 16790/16790 [==============================] - 11s 629us/step - loss: 0.0726 - plcc_metric: 0.9459 - mean_squared_error: 0.0186 - val_loss: 0.1008 - val_plcc_metric: 0.9253 - val_mean_squared_error: 0.0261
# Epoch 19/2000
# 16790/16790 [==============================] - 11s 640us/step - loss: 0.0720 - plcc_metric: 0.9466 - mean_squared_error: 0.0186 - val_loss: 0.1026 - val_plcc_metric: 0.9242 - val_mean_squared_error: 0.0268
# Epoch 20/2000
# 16790/16790 [==============================] - 11s 628us/step - loss: 0.0711 - plcc_metric: 0.9472 - mean_squared_error: 0.0183 - val_loss: 0.1021 - val_plcc_metric: 0.9248 - val_mean_squared_error: 0.0269
# Epoch 21/2000
# 16790/16790 [==============================] - 11s 634us/step - loss: 0.0705 - plcc_metric: 0.9478 - mean_squared_error: 0.0183 - val_loss: 0.1003 - val_plcc_metric: 0.9260 - val_mean_squared_error: 0.0263
# Epoch 22/2000
# 16790/16790 [==============================] - 11s 633us/step - loss: 0.0709 - plcc_metric: 0.9473 - mean_squared_error: 0.0181 - val_loss: 0.1016 - val_plcc_metric: 0.9254 - val_mean_squared_error: 0.0271
# Epoch 23/2000
# 16790/16790 [==============================] - 11s 638us/step - loss: 0.0702 - plcc_metric: 0.9480 - mean_squared_error: 0.0182 - val_loss: 0.1000 - val_plcc_metric: 0.9262 - val_mean_squared_error: 0.0262
# Epoch 24/2000
# 16790/16790 [==============================] - 10s 623us/step - loss: 0.0689 - plcc_metric: 0.9490 - mean_squared_error: 0.0179 - val_loss: 0.1000 - val_plcc_metric: 0.9260 - val_mean_squared_error: 0.0261
# Epoch 25/2000
# 16790/16790 [==============================] - 11s 632us/step - loss: 0.0684 - plcc_metric: 0.9491 - mean_squared_error: 0.0176 - val_loss: 0.1019 - val_plcc_metric: 0.9247 - val_mean_squared_error: 0.0266
# Epoch 26/2000
# 16790/16790 [==============================] - 11s 641us/step - loss: 0.0686 - plcc_metric: 0.9491 - mean_squared_error: 0.0178 - val_loss: 0.1015 - val_plcc_metric: 0.9254 - val_mean_squared_error: 0.0268
# Epoch 27/2000
# 16790/16790 [==============================] - 11s 644us/step - loss: 0.0675 - plcc_metric: 0.9499 - mean_squared_error: 0.0174 - val_loss: 0.1007 - val_plcc_metric: 0.9255 - val_mean_squared_error: 0.0262
# Epoch 28/2000
# 16790/16790 [==============================] - 11s 638us/step - loss: 0.0673 - plcc_metric: 0.9500 - mean_squared_error: 0.0173 - val_loss: 0.1013 - val_plcc_metric: 0.9254 - val_mean_squared_error: 0.0267
# Epoch 29/2000
# 16790/16790 [==============================] - 11s 631us/step - loss: 0.0660 - plcc_metric: 0.9510 - mean_squared_error: 0.0170 - val_loss: 0.1020 - val_plcc_metric: 0.9245 - val_mean_squared_error: 0.0264
# Epoch 30/2000
# 16790/16790 [==============================] - 11s 626us/step - loss: 0.0662 - plcc_metric: 0.9509 - mean_squared_error: 0.0171 - val_loss: 0.1009 - val_plcc_metric: 0.9254 - val_mean_squared_error: 0.0264
# Epoch 31/2000
# 16790/16790 [==============================] - 10s 617us/step - loss: 0.0652 - plcc_metric: 0.9515 - mean_squared_error: 0.0168 - val_loss: 0.1017 - val_plcc_metric: 0.9252 - val_mean_squared_error: 0.0269
#
# Epoch 00031: ReduceLROnPlateau reducing learning rate to 0.0009999999776482583.
# Epoch 32/2000
# 16790/16790 [==============================] - 11s 626us/step - loss: 0.0634 - plcc_metric: 0.9528 - mean_squared_error: 0.0162 - val_loss: 0.1008 - val_plcc_metric: 0.9255 - val_mean_squared_error: 0.0264
# Epoch 33/2000
# 16790/16790 [==============================] - 11s 629us/step - loss: 0.0637 - plcc_metric: 0.9526 - mean_squared_error: 0.0163 - val_loss: 0.1011 - val_plcc_metric: 0.9253 - val_mean_squared_error: 0.0263
# Epoch 34/2000
# 16790/16790 [==============================] - 11s 669us/step - loss: 0.0631 - plcc_metric: 0.9530 - mean_squared_error: 0.0161 - val_loss: 0.1010 - val_plcc_metric: 0.9254 - val_mean_squared_error: 0.0264
# Epoch 35/2000
# 16790/16790 [==============================] - 11s 666us/step - loss: 0.0633 - plcc_metric: 0.9529 - mean_squared_error: 0.0162 - val_loss: 0.1007 - val_plcc_metric: 0.9256 - val_mean_squared_error: 0.0263
# Epoch 36/2000
# 16790/16790 [==============================] - 11s 641us/step - loss: 0.0639 - plcc_metric: 0.9526 - mean_squared_error: 0.0164 - val_loss: 0.1006 - val_plcc_metric: 0.9257 - val_mean_squared_error: 0.0263
# Epoch 37/2000
# 16790/16790 [==============================] - 11s 639us/step - loss: 0.0630 - plcc_metric: 0.9531 - mean_squared_error: 0.0161 - val_loss: 0.1007 - val_plcc_metric: 0.9256 - val_mean_squared_error: 0.0263
# Epoch 38/2000
# 16790/16790 [==============================] - 10s 625us/step - loss: 0.0640 - plcc_metric: 0.9523 - mean_squared_error: 0.0164 - val_loss: 0.1008 - val_plcc_metric: 0.9255 - val_mean_squared_error: 0.0263
# Epoch 39/2000
# 16790/16790 [==============================] - 11s 649us/step - loss: 0.0640 - plcc_metric: 0.9523 - mean_squared_error: 0.0164 - val_loss: 0.1009 - val_plcc_metric: 0.9255 - val_mean_squared_error: 0.0264
# Epoch 40/2000
# 16790/16790 [==============================] - 11s 665us/step - loss: 0.0630 - plcc_metric: 0.9530 - mean_squared_error: 0.0160 - val_loss: 0.1010 - val_plcc_metric: 0.9254 - val_mean_squared_error: 0.0264
# Epoch 41/2000
# 16790/16790 [==============================] - 10s 615us/step - loss: 0.0631 - plcc_metric: 0.9531 - mean_squared_error: 0.0162 - val_loss: 0.1011 - val_plcc_metric: 0.9253 - val_mean_squared_error: 0.0265
#
# Epoch 00041: ReduceLROnPlateau reducing learning rate to 9.999999310821295e-05.
# Restoring model weights from the end of the best epoch
# Epoch 00041: early stopping

# %%
pd.DataFrame(hist.history).to_csv('/DAS_Storage4/ijjin/Study_2/220921_Final/Single/NCI_ALMANAC_mono/Result/221114_Frozen_Training/221114_Frozen_Training.csv')

# %%
NCI_ALMANAC_randomized.iloc[training_Response_list].to_csv('/DAS_Storage4/ijjin/Study_2/220921_Final/Single/NCI_ALMANAC_mono/Result/221114_Frozen_Training/221114_Training_df.csv')
NCI_ALMANAC_randomized.iloc[validation_Response_list].to_csv('/DAS_Storage4/ijjin/Study_2/220921_Final/Single/NCI_ALMANAC_mono/Result/221114_Frozen_Training/221114_Validation_df.csv')
NCI_ALMANAC_randomized.iloc[test_Response_list].to_csv('/DAS_Storage4/ijjin/Study_2/220921_Final/Single/NCI_ALMANAC_mono/Result/221114_Frozen_Training/221114_Test_df.csv')

# %%
NCI60_model.save('/DAS_Storage4/ijjin/Study_2/220921_Final/Single/NCI_ALMANAC_mono/Result/221114_Frozen_Training/221114_Frozen_Training.hdf5')

# %%
NCI60_model.evaluate([df.iloc[test_Response_list] for df in X_origin],NCI_ALMANAC_randomized.iloc[test_Response_list].PERCENTGROWTH)
# Out:
# 2098/2098 [==============================] - 6s 3ms/step
# [0.09694990414852638, 0.9286635251017953, 0.025613429490032938]

# %%
test_predicted=NCI60_model.predict([df.iloc[test_Response_list] for df in X_origin])
test_predicted=[x[0] for x in test_predicted]
test_df=NCI_ALMANAC_randomized.iloc[test_Response_list]
test_df['predicted']=test_predicted
test_df.to_csv('/DAS_Storage4/ijjin/Study_2/220921_Final/Single/NCI_ALMANAC_mono/Result/221114_Frozen_Training/221114_Predicted_test_df.csv')
# Out:
# /usr/local/lib/python3.7/site-packages/ipykernel_launcher.py:4: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   after removing the cwd from sys.path.

# %%
plot=sns.jointplot(test_df.PERCENTGROWTH,test_df.predicted)
plot.ax_joint.set_xlim(0,2)
plot.ax_joint.set_ylim(0,2)
plot.ax_joint.plot([0,2], [0,2], 'r', linewidth = 2)
plt.savefig('/DAS_Storage4/ijjin/Study_2/220921_Final/Single/NCI_ALMANAC_mono/Result/221114_Frozen_Training/221114_Frozen_Full.pdf')
# Out:
# /usr/local/lib/python3.7/site-packages/seaborn/_decorators.py:43: FutureWarning: Pass the following variables as keyword args: x, y. From version 0.12, the only valid positional argument will be `data`, and passing other arguments without an explicit keyword will result in an error or misinterpretation.
#   FutureWarning
